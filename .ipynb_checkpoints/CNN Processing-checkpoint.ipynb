# %% [markdown]
# **CNNs (Convolutional Neural Networks) for MRI**
#
# Basic Steps for building CNN model
#
# 1. Import deep learning libraries (in this case I chose Tensorflow and Keras)
# 2. Process image data (resizing/normalizing/augmenting, and splitting into training and testing sets)
# 3. Defining model architecture: specify number and size of convolutional and pooling layers, activation functions and number of neurons in fully connected layers. Usually activation functions are ReLU (rectified linear units). We can also use pre-trained models w/ transfer learning and improve accuracy of models (most commonly used algorithms are VGG16 and ResNet50; ImageNet is most commonly used pre-training dataset)
# 4. Compile the model (specify loss function/optimizer/evaluation metrics used to train and evaluate model)
# 5. Train model on training data with 'fit' function and evaluate with 'evaluate' function
# 6. Use trained model to make predictions on testing data with 'predict' function

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
import keras
from keras.models import Sequential
from tensorflow.keras.layers import (BatchNormalization, Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D)
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc

# %%
train_data_dir = './train'
test_data_dir = './test'
brain_mri_dir = './brain_mri_data'

# %%
import os
import shutil
import random
from sklearn.model_selection import train_test_split

# Define path to image folder and list subdirectories
path = 'C:/Users/etsai/OneDrive - University of North Carolina at Chapel Hill/STOR 565/CNN - Final Project/brain mri data'
classes = os.listdir(path)

# Create directories for train, validation, and test data
train_path = './brain_mri_train'
val_path = './brain_mri_val'
test_path = './brain_mri_test'
os.makedirs(train_path, exist_ok=True)
os.makedirs(val_path, exist_ok=True)
os.makedirs(test_path, exist_ok=True)

#64% training, 16% validation, 20% testing

# Copy images into train, validation, and test directories
for class_name in classes:
    class_path = os.path.join(path, class_name)
    files = os.listdir(class_path)
    # Split into train and test
    train_files, test_files = train_test_split(files, test_size=0.2, random_state=42)
    # Split train into train and validation
    train_files, val_files = train_test_split(train_files, test_size=0.2, random_state=42)
    for file_name in train_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(train_path, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)
    for file_name in val_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(val_path, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)
    for file_name in test_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(test_path, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)

# %%
datagen = ImageDataGenerator(rescale=1./255) #rescales pixel values so all pixel values fall within same range

batch_size = 32 #number of training examples in one forward/backward pass. higher batch size = more memory space needed

train_generator = datagen.flow_from_directory(
        train_path,
        target_size=(150, 150), #resized to 150px by 150px
        batch_size=batch_size,
        class_mode='categorical') #class_mode = 'categorical' one-hot code

validation_generator = datagen.flow_from_directory(
        test_path,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical')
print(train_generator.class_indices)
# Out:
# Found 2609 images belonging to 4 classes.
# Found 655 images belonging to 4 classes.
# {'glioma_tumor': 0, 'meningioma_tumor': 1, 'no_tumor': 2, 'pituitary_tumor': 3}

# %%
# Define path to image folder and list subdirectories
path = 'C:/Users/etsai/OneDrive - University of North Carolina at Chapel Hill/STOR 565/CNN - Final Project/binary class'
classes = os.listdir(path)

# Create directories for train, validation, and test data
train_path_bin = './binary_train'
val_path_bin = './binary_val'
test_path_bin = './binary_test'
os.makedirs(train_path_bin, exist_ok=True)
os.makedirs(val_path_bin, exist_ok=True)
os.makedirs(test_path_bin, exist_ok=True)

#64% training, 16% validation, 20% testing

# Copy images into train, validation, and test directories
for class_name in classes:
    class_path = os.path.join(path, class_name)
    files = os.listdir(class_path)
    # Split into train and test
    train_files, test_files = train_test_split(files, test_size=0.2, random_state=42)
    # Split train into train and validation
    train_files, val_files = train_test_split(train_files, test_size=0.2, random_state=42)
    for file_name in train_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(train_path_bin, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)
    for file_name in val_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(val_path_bin, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)
    for file_name in test_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(test_path_bin, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)

datagen_bin = ImageDataGenerator(rescale=1./255) #rescales pixel values so all pixel values fall within same range

batch_size = 32 #number of training examples in one forward/backward pass. higher batch size = more memory space needed

train_gen_bin = datagen_bin.flow_from_directory(
        train_path_bin,
        target_size=(150, 150), #resized to 150px by 150px
        batch_size=batch_size,
        class_mode='categorical') #class_mode = 'categorical' one-hot code

validation_gen_bin = datagen_bin.flow_from_directory(
        val_path_bin,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical')
test_gen_bin = datagen_bin.flow_from_directory(
        test_path_bin,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical')
print(train_gen_bin.class_indices)
# Out:
# Found 2088 images belonging to 2 classes.
# Found 523 images belonging to 2 classes.
# Found 653 images belonging to 2 classes.
# {'no tumor': 0, 'tumor': 1}

# %%
#binary vgg model version
binconv = VGG16(input_shape= (150, 150, 3),weights='imagenet',include_top=False)
binconv.output
for layer in binconv.layers:
    layer.trainable = False

x = binconv.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024,activation='relu')(x)
x = Dense(1024,activation='relu')(x)
x = Dense(512, activation='relu')(x)
x=  Dropout(.2)(x)
pred_bin = Dense(2,activation='softmax')(x)
binary_vgg = Model(inputs = binconv.input,outputs=pred_bin)

binary_vgg.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])


step_size_train_bin=train_gen_bin.n//train_gen_bin.batch_size

binary_history = binary_vgg.fit(train_gen_bin, steps_per_epoch=step_size_train_bin, epochs=50,  verbose=1, validation_data=validation_gen_bin)
# Out:
# Epoch 1/50
# 65/65 [==============================] - 218s 3s/step - loss: 0.3322 - accuracy: 0.8735 - val_loss: 0.2452 - val_accuracy: 0.9006
# Epoch 2/50
# 65/65 [==============================] - 255s 4s/step - loss: 0.1824 - accuracy: 0.9309 - val_loss: 0.1613 - val_accuracy: 0.9465
# Epoch 3/50
# 65/65 [==============================] - 304s 5s/step - loss: 0.1553 - accuracy: 0.9465 - val_loss: 0.1766 - val_accuracy: 0.9273
# Epoch 4/50
# 65/65 [==============================] - 270s 4s/step - loss: 0.1166 - accuracy: 0.9587 - val_loss: 0.1158 - val_accuracy: 0.9503
# Epoch 5/50
# 65/65 [==============================] - 281s 4s/step - loss: 0.0977 - accuracy: 0.9650 - val_loss: 0.0842 - val_accuracy: 0.9637
# Epoch 6/50
# 65/65 [==============================] - 314s 5s/step - loss: 0.1050 - accuracy: 0.9625 - val_loss: 0.0809 - val_accuracy: 0.9618
# Epoch 7/50
# 65/65 [==============================] - 331s 5s/step - loss: 0.0730 - accuracy: 0.9737 - val_loss: 0.1189 - val_accuracy: 0.9541
# Epoch 8/50
# 65/65 [==============================] - 330s 5s/step - loss: 0.0741 - accuracy: 0.9732 - val_loss: 0.0930 - val_accuracy: 0.9694
# Epoch 9/50
# 65/65 [==============================] - 3371s 53s/step - loss: 0.0562 - accuracy: 0.9805 - val_loss: 0.1678 - val_accuracy: 0.9541
# Epoch 10/50
# 65/65 [==============================] - 600s 9s/step - loss: 0.0841 - accuracy: 0.9679 - val_loss: 0.1075 - val_accuracy: 0.9579
# Epoch 11/50
# 65/65 [==============================] - 61728s 912s/step - loss: 0.0691 - accuracy: 0.9791 - val_loss: 0.0864 - val_accuracy: 0.9694
# Epoch 13/50
# 65/65 [==============================] - 220s 3s/step - loss: 0.0341 - accuracy: 0.9874 - val_loss: 0.0875 - val_accuracy: 0.9751
# Epoch 14/50
step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.1223 - val_accuracy: 0.9732
# Epoch 37/50
# 65/65 [==============================] - 234s 4s/step - loss: 3.4484e-04 - accuracy: 1.0000 - val_loss: 0.1532 - val_accuracy: 0.9751
# Epoch 38/50
# 65/65 [==============================] - 226s 3s/step - loss: 9.6657e-05 - accuracy: 1.0000 - val_loss: 0.1601 - val_accuracy: 0.9751
# Epoch 39/50
# 65/65 [==============================] - 231s 4s/step - loss: 5.1787e-05 - accuracy: 1.0000 - val_loss: 0.1669 - val_accuracy: 0.9751
# Epoch 40/50
# 65/65 [==============================] - 245s 4s/step - loss: 4.0277e-05 - accuracy: 1.0000 - val_loss: 0.1722 - val_accuracy: 0.9751
# Epoch 41/50
# 65/65 [==============================] - 260s 4s/step - loss: 3.9129e-05 - accuracy: 1.0000 - val_loss: 0.1752 - val_accuracy: 0.9751
# Epoch 42/50
# 65/65 [==============================] - 260s 4s/step - loss: 2.8863e-05 - accuracy: 1.0000 - val_loss: 0.1781 - val_accuracy: 0.9751
# Epoch 43/50
# 65/65 [==============================] - 257s 4s/step - loss: 2.6791e-05 - accuracy: 1.0000 - val_loss: 0.1790 - val_accuracy: 0.9751
# Epoch 44/50
# 65/65 [==============================] - 241s 4s/step - loss: 2.0477e-05 - accuracy: 1.0000 - val_loss: 0.1833 - val_accuracy: 0.9751
# Epoch 45/50
# 65/65 [==============================] - 244s 4s/step - loss: 1.5624e-05 - accuracy: 1.0000 - val_loss: 0.1860 - val_accuracy: 0.9751
# Epoch 46/50
# 65/65 [==============================] - 272s 4s/step - loss: 1.9970e-05 - accuracy: 1.0000 - val_loss: 0.1893 - val_accuracy: 0.9751
# Epoch 47/50
# 65/65 [==============================] - 244s 4s/step - loss: 9.8900e-06 - accuracy: 1.0000 - val_loss: 0.1915 - val_accuracy: 0.9751
# Epoch 48/50
# 65/65 [==============================] - 244s 4s/step - loss: 1.1108e-05 - accuracy: 1.0000 - val_loss: 0.1941 - val_accuracy: 0.9751
# Epoch 49/50
# 65/65 [==============================] - 250s 4s/step - loss: 9.0168e-06 - accuracy: 1.0000 - val_loss: 0.1986 - val_accuracy: 0.9751
# Epoch 50/50
# 65/65 [==============================] - 241s 4s/step - loss: 8.7238e-06 - accuracy: 1.0000 - val_loss: 0.1997 - val_accuracy: 0.9751

# %%
#binary vgg model
Y_pred_vgg_bin = binary_vgg.predict(test_gen_bin)
testy_vgg_bin = test_gen_bin.classes

# Convert predictions from one-hot encoding to class labels
Y_pred_classes_vgg_bin = np.argmax(Y_pred_vgg_bin, axis=1)

# Generate the classification report
print('Classification Report')
target_names_bin = ['No Tumor','Tumor']
print(classification_report(testy_vgg_bin, Y_pred_classes_vgg_bin, target_names=target_names_bin))
# Out:
# 21/21 [==============================] - 59s 3s/step
# Classification Report
#               precision    recall  f1-score   support
#
#     No Tumor       0.11      0.11      0.11       100
#        Tumor       0.84      0.84      0.84       553
#
#     accuracy                           0.73       653
#    macro avg       0.48      0.48      0.48       653
# weighted avg       0.73      0.73      0.73       653

# %%
# Define path to image folder and list subdirectories
path = 'C:/Users/etsai/OneDrive - University of North Carolina at Chapel Hill/STOR 565/CNN - Final Project/tumor class'
classes = os.listdir(path)

# Create directories for train, validation, and test data
train_path_tum = './tum_train'
val_path_tum = './tum_val'
test_path_tum = './tum_test'
os.makedirs(train_path_tum, exist_ok=True)
os.makedirs(val_path_tum, exist_ok=True)
os.makedirs(test_path_tum, exist_ok=True)

#64% training, 16% validation, 20% testing

# Copy images into train, validation, and test directories
for class_name in classes:
    class_path = os.path.join(path, class_name)
    files = os.listdir(class_path)
    # Split into train and test
    train_files, test_files = train_test_split(files, test_size=0.2, random_state=42)
    # Split train into train and validation
    train_files, val_files = train_test_split(train_files, test_size=0.2, random_state=42)
    for file_name in train_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(train_path_tum, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)
    for file_name in val_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(val_path_tum, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)
    for file_name in test_files:
        src_path = os.path.join(class_path, file_name)
        dst_path = os.path.join(test_path_tum, class_name, file_name)
        os.makedirs(os.path.dirname(dst_path), exist_ok=True)
        shutil.copy(src_path, dst_path)

datagen_tum = ImageDataGenerator(rescale=1./255) #rescales pixel values so all pixel values fall within same range

batch_size = 32 #number of training examples in one forward/backward pass. higher batch size = more memory space needed

train_gen_tum = datagen_bin.flow_from_directory(
        train_path_tum,
        target_size=(150, 150), #resized to 150px by 150px
        batch_size=batch_size,
        class_mode='categorical') #class_mode = 'categorical' one-hot code

validation_gen_tum = datagen_tum.flow_from_directory(
        val_path_bin,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical')
test_gen_tum = datagen_tum.flow_from_directory(
        test_path_tum,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical')
print(train_gen_tum.class_indices)
# Out:
# Found 1767 images belonging to 3 classes.
# Found 442 images belonging to 3 classes.
# Found 555 images belonging to 3 classes.
# {'glioma': 0, 'meningioma': 1, 'pituitary': 2}

# %%
#only tumor classification

tumconv = VGG16(input_shape= (150, 150, 3),weights='imagenet',include_top=False)
tumconv.output
for layer in binconv.layers:
    layer.trainable = False

x = tumconv.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024,activation='relu')(x)
x = Dense(1024,activation='relu')(x)
x = Dense(512, activation='relu')(x)
x=  Dropout(.2)(x)
pred_tum = Dense(3,activation='softmax')(x)
tum_vgg = Model(inputs = tumconv.input,outputs=pred_tum)

tum_vgg.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])


step_size_train_tum=train_gen_tum.n//train_gen_tum.batch_size

tum_history = tum_vgg.fit(train_gen_tum, steps_per_epoch=step_size_train_tum, epochs=50,  verbose=1, validation_data=validation_gen_tum)
# Out:
# Epoch 1/50
# 55/55 [==============================] - 683s 12s/step - loss: 1.7391 - accuracy: 0.3308 - val_loss: 1.0986 - val_accuracy: 0.3348
# Epoch 2/50
# 55/55 [==============================] - 643s 12s/step - loss: 1.0991 - accuracy: 0.3349 - val_loss: 1.0986 - val_accuracy: 0.3348
# Epoch 3/50
# 55/55 [==============================] - 641s 12s/step - loss: 1.0989 - accuracy: 0.3199 - val_loss: 1.0985 - val_accuracy: 0.3394
# Epoch 4/50
# 55/55 [==============================] - 1932s 36s/step - loss: 1.0988 - accuracy: 0.3291 - val_loss: 1.0985 - val_accuracy: 0.3394
# Epoch 5/50
# 55/55 [==============================] - 3858s 71s/step - loss: 1.0986 - accuracy: 0.3406 - val_loss: 1.0985 - val_accuracy: 0.3394
# Epoch 6/50
# 55/55 [==============================] - 1155s 21s/step - loss: 1.0988 - accuracy: 0.3395 - val_loss: 1.0985 - val_accuracy: 0.3394
# Epoch 7/50
# 55/55 [==============================] - 1437s 26s/step - loss: 1.0986 - accuracy: 0.3401 - val_loss: 1.0985 - val_accuracy: 0.3394
# Epoch 8/50
# 55/55 [==============================] - 1332s 24s/step - loss: 1.0989 - accuracy: 0.3343 - val_loss: 1.0985 - val_accuracy: 0.3348
# Epoch 9/50
# 29/55 [==============>...............] - ETA: 8:21 - loss: 1.0979 - accuracy: 0.3499

# %%
#tumor vgg model
Y_pred_vgg_tum = tum_vgg.predict(test_gen_tum)
testy_vgg_tum = test_gen_tum.classes

# Convert predictions from one-hot encoding to class labels
Y_pred_classes_vgg_tum = np.argmax(Y_pred_vgg_tum, axis=1)

# Generate the classification report
print('Classification Report')
target_names_bin = ['No Tumor','Tumor']
print(classification_report(testy_vgg_tum, Y_pred_classes_vgg_tum, target_names=target_names_tum))

# %%
model = tf.keras.models.Sequential([ #initiate sequential model object (linear stack of layers)
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(150, 150, 3)), #adds 2D convolutional layer w/ 16 filters size 3x3. input shape = 150x150 pixels with 3 color channels (RBG)
    tf.keras.layers.MaxPooling2D(2,2), #adds 2D max pooling layer to model, downsampling input by taking max value of 2x2 window in input feature map
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(), #flattens input feature map into 1D vector to be passed to fully connected layer
    tf.keras.layers.Dense(512, activation='relu'), #adds fully connected layer w/ 512 unit and ReLU activation
    tf.keras.layers.Dense(4, activation='softmax')  #adds fully connected layer with 4 units (one for each class) and softmax activation
])

#softmax function converts output into probability distribution over 4 classes

#resulted in accuracy of around 74%

# %%
#model version 2 based on "Accurate brain tumor detection using deep convolutional neural network"
ini_input = keras.Input(shape=(150, 150, 3), name="image")

x1 = layers.Conv2D(64, (22, 22), strides=2)(ini_input)
x1 = layers.MaxPooling2D((3, 3))(x1)
x1 = layers.BatchNormalization()(x1)

x2 = layers.Conv2D(128, (11, 11), strides=2, padding="same")(x1)
x2 = layers.MaxPooling2D((2, 2))(x2)
x2 = layers.BatchNormalization()(x2)

x3 = layers.Conv2D(256, (7, 7), strides=2, padding="same")(x2)
x3 = layers.MaxPooling2D((2, 2))(x3)
x3 = layers.BatchNormalization()(x3)

x4 = layers.Conv2D(512, (3, 3), strides=2, padding="same")(x3)
x4 = layers.MaxPooling2D((2, 2), padding='same')(x4)
x4 = layers.BatchNormalization()(x4)
x4 = layers.Activation("relu")(x4)

x5 = layers.GlobalAveragePooling2D()(x4)
x5 = layers.Dense(1024, activation="relu")(x5)
x5 = layers.BatchNormalization()(x5)

x6 = layers.Dense(512, activation="relu")(x5)
x6 = layers.BatchNormalization()(x6)

x7 = layers.Dense(256, activation="relu")(x6)
x7 = layers.BatchNormalization()(x7)

x8 = layers.Dropout(.2)(x7)
x9 = layers.Dense(4, activation="softmax")(x8)

model_v2 = keras.Model(inputs=ini_input, outputs=x9)

# %% [markdown]
# categorical cross-entropy is used for multi-class classification problems
# - it measures dissimilarity between predicted probability distribution over all possible classes and true probability distribution.
# - the predicted probability distribution is vector of probabilities,
# - each element represents probability of corresponding class
# - true probability distribution is also vector with value of 1 for true class and 0 for all other classes.
#
# categorical cross entropy = avg. of cross-entropy loss over all samples in dataset. measures how well predicted probability distribution matches true probability distribution; is used as objective function in training to update model parameter to minimize loss.
#
# categorical cross-entropy loss for single sample is given by:
#
# L = - ∑ y_i * log(p_i)
#
# y_i = true probability distribuiton (one-hot encoded vector)
# p_i is predicted probability distribution (softmax output) for i-th class.

# %%
#og basic model
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

history = model.fit(train_generator,
                    steps_per_epoch=train_generator.
# Epoch 78/80
# 89/89 [==============================] - 41s 454ms/step - loss: 1.1421e-06 - accuracy: 1.0000 - val_loss: 9.8206 - val_accuracy: 0.7214
# Epoch 79/80
# 89/89 [==============================] - 43s 480ms/step - loss: 1.0727e-06 - accuracy: 1.0000 - val_loss: 9.9090 - val_accuracy: 0.7214
# Epoch 80/80
# 89/89 [==============================] - 41s 463ms/step - loss: 1.0332e-06 - accuracy: 1.0000 - val_loss: 9.6146 - val_accuracy: 0.7266

# %%
test_generator = datagen.flow_from_directory(
        test_data_dir,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

model.evaluate(test_generator)
# Out:
# Found 394 images belonging to 4 classes.
# 13/13 [==============================] - 2s 143ms/step - loss: 9.7082 - accuracy: 0.7234
# [9.708248138427734, 0.7233502268791199]

# %%
Y_pred = model.predict(test_generator)
testy = test_generator.classes

# Convert predictions from one-hot encoding to class labels
Y_pred_classes = np.argmax(Y_pred, axis=1)

# Generate the classification report
print('Classification Report')
target_names = ['Glioma','Meningioma', 'No Tumor', 'Pituitary']
print(classification_report(testy, Y_pred_classes, target_names=target_names))
# Out:
# 13/13 [==============================] - 2s 173ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#       Glioma       0.90      0.18      0.30       100
#   Meningioma       0.71      0.99      0.83       115
#     No Tumor       0.65      1.00      0.79       105
#    Pituitary       0.92      0.65      0.76        74
#
#     accuracy                           0.72       394
#    macro avg       0.80      0.70      0.67       394
# weighted avg       0.78      0.72      0.67       394

# %% [markdown]
# The 'basic' model correctly identified % of images in the dataset. The model's loss value on the dataset was 5.72. Loss value is equal to the average difference between predicted output of the model and actual output.

# %%
#pre-made model
model_v2.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

history_v2 = model_v2.fit(train_generator,
                    steps_per_epoch=train_generator.n//train_generator.batch_size,
                    epochs=80,
                    validation_data=validation_generator,
                    validation_steps=validation_generator.n//validation_generator.batch_size)
# Out:
# Epoch 1/80
# 89/89 [==============================] - 115s 1s/step - loss: 1.0396 - accuracy: 0.6180 - val_loss: 3.9780 - val_accuracy: 0.2578
# Epoch 2/80
# 89/89 [==============================] - 101s 1s/step - loss: 0.7133 - accuracy: 0.7241 - val_loss: 2.3187 - val_accuracy: 0.4271
# Epoch 3/80
# 89/89 [==============================] - 121s 1s/step - loss: 0.5490 - accuracy: 0.7875 - val_loss: 2.6314 - val_accuracy: 0.3516
# Epoch 4/80
# 89/89 [==============================] - 153s 2s/step - loss: 0.4295 - accuracy: 0.8460 - val_loss: 2.6268 - val_accuracy: 0.5651
# Epoch 5/80
# 89/89 [==============================] - 149s 2s/step - loss: 0.3936 - accuracy: 0.8499 - val_loss: 2.9447 - val_accuracy: 0.4323
# Epoch 6/80
# 89/89 [==============================] - 146s 2s/step - loss: 0.3159 - accuracy: 0.8876 - val_loss: 6.0786 - val_accuracy: 0.3307
# Epoch 7/80
# 89/89 [==============================] - 148s 2s/step - loss: 0.2159 - accuracy: 0.9211 - val_loss: 3.9104 - val_accuracy: 0.3776
# Epoch 8/80
# 89/89 [==============================] - 118s 1s/step - loss: 0.1853 - accuracy: 0.9408 - val_loss: 7.0894 - val_accuracy: 0.3594
# Epoch 9/80
# 89/89 [==============================] - 115s 1s/step - loss: 0.1798 - accuracy: 0.9390 - val_loss: 2.0514 - val_accuracy: 0.6953
# Epoch 10/80
step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 2.0433 - val_accuracy: 0.7578
# Epoch 78/80
# 89/89 [==============================] - 167s 2s/step - loss: 0.0078 - accuracy: 0.9979 - val_loss: 2.3491 - val_accuracy: 0.7734
# Epoch 79/80
# 89/89 [==============================] - 172s 2s/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 2.0497 - val_accuracy: 0.7734
# Epoch 80/80
# 89/89 [==============================] - 170s 2s/step - loss: 0.0045 - accuracy: 0.9975 - val_loss: 2.4745 - val_accuracy: 0.7656

# %%
#premade model
test_generator_v2 = datagen.flow_from_directory(
        test_data_dir,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)

model_v2.evaluate(test_generator_v2)
# Out:
# Found 394 images belonging to 4 classes.
# 13/13 [==============================] - 8s 633ms/step - loss: 2.4117 - accuracy: 0.7716
# [2.4117071628570557, 0.7715736031532288]

# %%
#premade model
Y_pred_2 = model_v2.predict(test_generator_v2)
testy_2 = test_generator_v2.classes

# Convert predictions from one-hot encoding to class labels
Y_pred_classes_2 = np.argmax(Y_pred_2, axis=1)

# Generate the classification report
print('Classification Report')
target_names = ['Glioma','Meningioma', 'No Tumor', 'Pituitary']
print(classification_report(testy_2, Y_pred_classes_2, target_names=target_names))
# Out:
# 13/13 [==============================] - 4s 317ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#       Glioma       1.00      0.18      0.31       100
#   Meningioma       0.75      0.99      0.85       115
#     No Tumor       0.70      1.00      0.83       105
#    Pituitary       0.89      0.91      0.90        74
#
#     accuracy                           0.77       394
#    macro avg       0.84      0.77      0.72       394
# weighted avg       0.83      0.77      0.72       394

# %%
#og model
import matplotlib.pyplot as plt
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic Performance of Basic Model', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(0,80))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 80, 1))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 80, 1))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
#pre-built model
import matplotlib.pyplot as plt
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic Performance of Pre-Built Model', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(0,80))
ax1.plot(epoch_list, history_v2.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history_v2.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 80, 1))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history_v2.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history_v2.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 80, 1))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %% [markdown]
# # Get predicted probabilities turn to code later
# y_prob = model_v2.predict(test_generator_v2)
#
# # Get false positive rate, true positive rate, and threshold values
# fpr, tpr, thresholds = roc_curve(test_generator_v2.classes, y_prob[:,1])
#
# # Plot ROC curve
# plt.plot(fpr, tpr)
# plt.title('ROC Curve')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.show()

# %%
conv = VGG16(input_shape= (150, 150, 3),weights='imagenet',include_top=False)
conv.output
for layer in conv.layers:
    layer.trainable = False
    
datagen_vgg = ImageDataGenerator(rescale=1/255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True, #this is all data augmentation
    width_shift_range=0.1,
    height_shift_range=0.1,
    vertical_flip=True,
    validation_split=0.2) #rescales pixel values so all pixel values fall within same range

batch_size = 32 #number of training examples in one forward/backward pass. higher batch size = more memory space needed

train_gen = datagen_vgg.flow_from_directory(
        train_path,
        target_size=(150, 150), #resized to 150px by 150px
        batch_size=batch_size,
        class_mode='categorical',
        shuffle = False) #class_mode = 'categorical' one-hot code

validation_gen = datagen_vgg.flow_from_directory(
        val_path,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle = False)
test_gen = datagen_vgg.flow_from_directory(
        test_path,
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 2087 images belonging to 4 classes.
# Found 522 images belonging to 4 classes.
# Found 655 images belonging to 4 classes.

# %%
#second vgg model version
x = conv.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024,activation='relu')(x)
x = Dense(1024,activation='relu')(x)
x = Dense(512, activation='relu')(x)
x=  Dropout(.2)(x)
pred = Dense(4,activation='softmax')(x)
vgg_model_2 = Model(inputs = conv.input,outputs=pred)

vgg_model_2.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
vgg_model = Sequential()
vgg_model.add(conv)
vgg_model.add(GlobalAveragePooling2D())
vgg_model.add(Dense(1024, activation='relu'))
vgg_model.add(Dropout(0.5))
vgg_model.add(Dense(512, activation='relu'))
vgg_model.add(Dropout(0.5))
vgg_model.add(Dense(4, activation='softmax'))

vgg_model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
step_size_train=train_gen.n//train_gen.batch_size
vgg_history = vgg_model.fit(train_gen, steps_per_epoch=step_size_train, epochs=50,  verbose=1, validation_data=validation_gen)
# Out:
# Epoch 1/50
# 65/65 [==============================] - 278s 4s/step - loss: 1.6175 - accuracy: 0.2964 - val_loss: 1.3277 - val_accuracy: 0.3467
# Epoch 2/50
# 65/65 [==============================] - 187s 3s/step - loss: 1.3615 - accuracy: 0.3942 - val_loss: 1.6368 - val_accuracy: 0.2835
# Epoch 3/50
# 65/65 [==============================] - 160s 2s/step - loss: 1.3173 - accuracy: 0.3270 - val_loss: 1.1963 - val_accuracy: 0.5651
# Epoch 4/50
# 65/65 [==============================] - 177s 3s/step - loss: 1.2619 - accuracy: 0.4453 - val_loss: 1.1661 - val_accuracy: 0.4215
# Epoch 5/50
# 65/65 [==============================] - 168s 3s/step - loss: 1.2763 - accuracy: 0.3883 - val_loss: 1.1276 - val_accuracy: 0.4866
# Epoch 6/50
# 65/65 [==============================] - 175s 3s/step - loss: 1.2154 - accuracy: 0.4676 - val_loss: 1.0919 - val_accuracy: 0.6034
# Epoch 7/50
# 65/65 [==============================] - 172s 3s/step - loss: 1.1403 - accuracy: 0.4730 - val_loss: 1.0837 - val_accuracy: 0.5613
# Epoch 8/50
# 65/65 [==============================] - 182s 3s/step - loss: 1.0392 - accuracy: 0.5625 - val_loss: 0.8762 - val_accuracy: 0.6322
# Epoch 9/50
# 65/65 [==============================] - 164s 3s/step - loss: 1.0222 - accuracy: 0.5601 - val_loss: 0.8495 - val_accuracy: 0.6437
# Epoch 10/50
# 65/65 [==============================] - 180s 3s/step - loss: 1.0744 - accuracy: 0.5455 - val_loss: 0.8716 - val_accuracy: 0.6801
# Epoch 11/50
# 65/65 [==============================] - 182s 3s/step - loss: 0.9501 - accuracy: 0.6146 - val_loss: 0.8631 - val_accuracy: 0.6667
# Epoch 12/50
# 65/65 [==============================] - 179s 3s/step - loss: 0.9296 - accuracy: 0.6073 - val_loss: 1.0839 - val_accuracy: 0.4828
# Epoch 13/50
# 65/65 [==============================] - 181s 3s/step - loss: 0.9226 - accuracy: 0.6200 - val_loss: 0.9151 - val_accuracy: 0.6475
# Epoch 14/50
# 65/65 [==============================] - 194s 3s/step - loss: 0.9534 - accuracy: 0.6107 - val_loss: 0.7722 - val_accuracy: 0.7050
# Epoch 15/50
# 65/65 [==============================] - 172s 3s/step - loss: 0.9243 - accuracy: 0.6107 - val_loss: 0.9091 - val_accuracy: 0.6667
# Epoch 16/50
# 65/65 [==============================] - 178s 3s/step - loss: 0.8287 - accuracy: 0.6506 - val_loss: 0.7715 - val_accuracy: 0.6935
# Epoch 37/50
# 65/65 [==============================] - 180s 3s/step - loss: 0.6862 - accuracy: 0.7251 - val_loss: 0.7019 - val_accuracy: 0.7318
# Epoch 38/50
# 65/65 [==============================] - 177s 3s/step - loss: 0.6896 - accuracy: 0.7290 - val_loss: 0.6972 - val_accuracy: 0.7414
# Epoch 39/50
# 65/65 [==============================] - 173s 3s/step - loss: 0.6751 - accuracy: 0.7270 - val_loss: 0.5941 - val_accuracy: 0.7529
# Epoch 40/50
# 65/65 [==============================] - 173s 3s/step - loss: 0.7071 - accuracy: 0.7372 - val_loss: 0.6379 - val_accuracy: 0.7548
# Epoch 41/50
# 65/65 [==============================] - 176s 3s/step - loss: 0.6816 - accuracy: 0.7280 - val_loss: 0.6047 - val_accuracy: 0.7759
# Epoch 42/50
# 65/65 [==============================] - 183s 3s/step - loss: 0.6646 - accuracy: 0.7328 - val_loss: 0.6372 - val_accuracy: 0.7644
# Epoch 43/50
# 65/65 [==============================] - 174s 3s/step - loss: 0.6601 - accuracy: 0.7455 - val_loss: 0.5687 - val_accuracy: 0.7835
# Epoch 44/50
# 65/65 [==============================] - 176s 3s/step - loss: 0.6605 - accuracy: 0.7436 - val_loss: 0.6534 - val_accuracy: 0.7548
# Epoch 45/50
# 65/65 [==============================] - 170s 3s/step - loss: 0.7161 - accuracy: 0.7105 - val_loss: 0.6385 - val_accuracy: 0.7548
# Epoch 46/50
# 65/65 [==============================] - 186s 3s/step - loss: 0.7042 - accuracy: 0.7100 - val_loss: 0.6264 - val_accuracy: 0.7337
# Epoch 47/50
# 65/65 [==============================] - 165s 3s/step - loss: 0.6847 - accuracy: 0.7309 - val_loss: 0.6710 - val_accuracy: 0.7146
# Epoch 48/50
# 65/65 [==============================] - 176s 3s/step - loss: 0.6704 - accuracy: 0.7377 - val_loss: 0.5996 - val_accuracy: 0.7797
# Epoch 49/50
# 65/65 [==============================] - 171s 3s/step - loss: 0.6632 - accuracy: 0.7421 - val_loss: 0.5792 - val_accuracy: 0.7816
# Epoch 50/50
# 65/65 [==============================] - 177s 3s/step - loss: 0.6149 - accuracy: 0.7616 - val_loss: 0.5620 - val_accuracy: 0.7854

# %%
step_size_train_2=train_gen.n//train_gen.batch_size
vgg_history_2 = vgg_model_2.fit(train_gen, steps_per_epoch=step_size_train, epochs=50,  verbose=1, validation_data=validation_gen)
# Out:
# Epoch 1/50
# 65/65 [==============================] - 153s 2s/step - loss: 1.6342 - accuracy: 0.3012 - val_loss: 1.3602 - val_accuracy: 0.2835
# Epoch 2/50
# 65/65 [==============================] - 164s 3s/step - loss: 1.3717 - accuracy: 0.3046 - val_loss: 1.3188 - val_accuracy: 0.4464
# Epoch 3/50
# 65/65 [==============================] - 166s 3s/step - loss: 1.3117 - accuracy: 0.3830 - val_loss: 1.1119 - val_accuracy: 0.5364
# Epoch 4/50
# 65/65 [==============================] - 177s 3s/step - loss: 1.2347 - accuracy: 0.4297 - val_loss: 1.0986 - val_accuracy: 0.4847
# Epoch 5/50
# 65/65 [==============================] - 172s 3s/step - loss: 1.1381 - accuracy: 0.4779 - val_loss: 0.9288 - val_accuracy: 0.6245
# 65/65 [==============================] - 514s 8s/step - loss: 0.5963 - accuracy: 0.7591 - val_loss: 0.6293 - val_accuracy: 0.7529
# Epoch 47/50
# 65/65 [==============================] - 489s 8s/step - loss: 0.5654 - accuracy: 0.7732 - val_loss: 0.5017 - val_accuracy: 0.8008
# Epoch 48/50
# 65/65 [==============================] - 251s 4s/step - loss: 0.6126 - accuracy: 0.7606 - val_loss: 0.5820 - val_accuracy: 0.7701
# Epoch 49/50
# 65/65 [==============================] - 249s 4s/step - loss: 0.5881 - accuracy: 0.7523 - val_loss: 0.5080 - val_accuracy: 0.8065
# Epoch 50/50
# 65/65 [==============================] - 260s 4s/step - loss: 0.5557 - accuracy: 0.7752 - val_loss: 0.5751 - val_accuracy: 0.7759

# %%
vgg_model.evaluate(test_gen)
# Out:
# 21/21 [==============================] - 66s 3s/step - loss: 1.4155 - accuracy: 0.3038
# [1.415480375289917, 0.3038167953491211]

# %%
vgg_model_2.evaluate(test_gen)
# Out:
# 21/21 [==============================] - 112s 5s/step - loss: 0.5877 - accuracy: 0.7603
# [0.5876894593238831, 0.7603053450584412]

# %%
#pretrained model
Y_pred_vgg = vgg_model.predict(test_gen)
testy_vgg = test_gen.classes

# Convert predictions from one-hot encoding to class labels
Y_pred_classes_vgg = np.argmax(Y_pred_vgg, axis=1)

# Generate the classification report
print('Classification Report')
target_names = ['Glioma','Meningioma', 'No Tumor', 'Pituitary']
print(classification_report(testy_vgg, Y_pred_classes_vgg, target_names=target_names))
# Out:
# 21/21 [==============================] - 40s 2s/step
# Classification Report
#               precision    recall  f1-score   support
#
#       Glioma       0.82      0.70      0.75       186
#   Meningioma       0.73      0.66      0.69       188
#     No Tumor       0.75      0.79      0.77       100
#    Pituitary       0.78      0.94      0.86       181
#
#     accuracy                           0.77       655
#    macro avg       0.77      0.77      0.77       655
# weighted avg       0.77      0.77      0.77       655

# %%
#pretrained model v2
Y_pred_vgg_2 = vgg_model_2.predict(test_gen)
testy_vgg_2 = test_gen.classes

# Convert predictions from one-hot encoding to class labels
Y_pred_classes_vgg_2 = np.argmax(Y_pred_vgg_2, axis=1)

# Generate the classification report
print('Classification Report')
target_names = ['Glioma','Meningioma', 'No Tumor', 'Pituitary']
print(classification_report(testy_vgg_2, Y_pred_classes_vgg_2, target_names=target_names))
# Out:
# 21/21 [==============================] - 104s 5s/step
# Classification Report
#               precision    recall  f1-score   support
#
#       Glioma       0.71      0.80      0.75       186
#   Meningioma       0.73      0.67      0.70       188
#     No Tumor       0.85      0.86      0.86       100
#    Pituitary       0.86      0.82      0.84       181
#
#     accuracy                           0.78       655
#    macro avg       0.79      0.79      0.79       655
# weighted avg       0.78      0.78      0.78       655

# %%
#pre-trained VGG16 model
import matplotlib.pyplot as plt
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic Performance of Pre-Trained VGG16 Model', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(0,50))
ax1.plot(epoch_list, vgg_history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, vgg_history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 50, 1))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, vgg_history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, vgg_history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 50, 1))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
#pre-trained VGG16 model
import matplotlib.pyplot as plt
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic Performance of Pre-Trained VGG16 Model V2', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(0,50))
ax1.plot(epoch_list, vgg_history_2.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, vgg_history_2.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 50, 1))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, vgg_history_2.history['loss'], label='Train Loss')
ax2.plot(epoch_list, vgg_history_2.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 50, 1))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
